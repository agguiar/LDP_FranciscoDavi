# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

# Gerando dados sintéticos de imóveis em Nova Iguaçu e Queimados
np.random.seed(42)
n_imoveis = 45

# Coordenadas base (Aproximadas)
# Nova Iguaçu: -22.756, -43.460
# Queimados: -22.716, -43.555

dados_imoveis = {
    'id_imovel': range(1, n_imoveis + 1),
    'cidade': np.where(np.random.rand(n_imoveis) > 0.4, 'Nova Iguaçu', 'Queimados'),
    'valor_venda': np.random.uniform(150000, 850000, n_imoveis).round(2),
    'tipo': np.random.choice(['Casa', 'Apartamento', 'Terreno'], n_imoveis)
}

df_mapa = pd.DataFrame(dados_imoveis)

# Atribuindo coordenadas com base na cidade adicionando uma pequena dispersão aleatória
def gerar_lat(cidade):
    if cidade == 'Nova Iguaçu':
        return -22.756 + np.random.uniform(-0.03, 0.03)
    return -22.716 + np.random.uniform(-0.02, 0.02)

def gerar_lon(cidade):
    if cidade == 'Nova Iguaçu':
        return -43.460 + np.random.uniform(-0.03, 0.03)
    return -43.555 + np.random.uniform(-0.02, 0.02)

df_mapa['latitude'] = df_mapa['cidade'].apply(gerar_lat)
df_mapa['longitude'] = df_mapa['cidade'].apply(gerar_lon)

# %% [markdown]
# # Parte 1
#
# Criar o mapa base

# %%
latitude_media = df_mapa['latitude'].mean()
longitude_media = df_mapa['longitude'].mean()

mapa = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d74fedf09ba6df80472d9085efa4f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d74fedf09ba6df80472d9085efa4f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d74fedf09ba6df80472d9085efa4f07 = L.map(
#                 &quot;map_6d74fedf09ba6df80472d9085efa4f07&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95ca82e8691717d8a190f745b5320ea3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95ca82e8691717d8a190f745b5320ea3.addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 5 primeiras linhas

# %%
for _, imovel in df_mapa.head(5).iterrows():
    folium.Marker(
        location=[imovel['latitude'], imovel['longitude']],
        popup=f"Tipo: {imovel['tipo']}<br>Valor de venda: R$ {imovel['valor_venda']:.2f}"
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d74fedf09ba6df80472d9085efa4f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d74fedf09ba6df80472d9085efa4f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d74fedf09ba6df80472d9085efa4f07 = L.map(
#                 &quot;map_6d74fedf09ba6df80472d9085efa4f07&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95ca82e8691717d8a190f745b5320ea3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95ca82e8691717d8a190f745b5320ea3.addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#             tile_layer_95ca82e8691717d8a190f745b5320ea3.addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#             var marker_193ba666252731dfbc70a2d27d1c9457 = L.marker(
#                 [-22.714426310323375, -43.57138840919782],
#                 {
# }
#             ).addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#         var popup_0db7c0caa8fe90379ad6287fd88da53b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62476095dde584c2f5fcca99aba3ffc6 = $(`&lt;div id=&quot;html_62476095dde584c2f5fcca99aba3ffc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Casa&lt;br&gt;Valor de venda: R$ 613765.60&lt;/div&gt;`)[0];
#                 popup_0db7c0caa8fe90379ad6287fd88da53b.setContent(html_62476095dde584c2f5fcca99aba3ffc6);
#
#
#
#         marker_193ba666252731dfbc70a2d27d1c9457.bindPopup(popup_0db7c0caa8fe90379ad6287fd88da53b)
#         ;
#
#
#
#
#             var marker_7c674b19a35d5932df16690aa96de9e4 = L.marker(
#                 [-22.73755359069016, -43.43988185026465],
#                 {
# }
#             ).addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#         var popup_32eae6a983f5566f32f5830a6a349de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae1bcd5307d3e5d55cbe20c7d1e94f88 = $(`&lt;div id=&quot;html_ae1bcd5307d3e5d55cbe20c7d1e94f88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Terreno&lt;br&gt;Valor de venda: R$ 368197.75&lt;/div&gt;`)[0];
#                 popup_32eae6a983f5566f32f5830a6a349de5.setContent(html_ae1bcd5307d3e5d55cbe20c7d1e94f88);
#
#
#
#         marker_7c674b19a35d5932df16690aa96de9e4.bindPopup(popup_32eae6a983f5566f32f5830a6a349de5)
#         ;
#
#
#
#
#             var marker_754eb46b6fe89ae84c9d7a86e5280d02 = L.marker(
#                 [-22.73223452200459, -43.4707531961017],
#                 {
# }
#             ).addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#         var popup_a24bf2917bec4b76978ebcea9e94e246 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6f83b7fe48dd02512dc5a486d8fdb79 = $(`&lt;div id=&quot;html_f6f83b7fe48dd02512dc5a486d8fdb79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Apartamento&lt;br&gt;Valor de venda: R$ 514047.61&lt;/div&gt;`)[0];
#                 popup_a24bf2917bec4b76978ebcea9e94e246.setContent(html_f6f83b7fe48dd02512dc5a486d8fdb79);
#
#
#
#         marker_754eb46b6fe89ae84c9d7a86e5280d02.bindPopup(popup_a24bf2917bec4b76978ebcea9e94e246)
#         ;
#
#
#
#
#             var marker_f55049459e821b1830ba004180e01a50 = L.marker(
#                 [-22.76691979150169, -43.47880888937601],
#                 {
# }
#             ).addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#         var popup_76c8bb6692e8bfda4400331f34af42ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93cadfe747e9c2ab075e3865485e1ec7 = $(`&lt;div id=&quot;html_93cadfe747e9c2ab075e3865485e1ec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Terreno&lt;br&gt;Valor de venda: R$ 532697.20&lt;/div&gt;`)[0];
#                 popup_76c8bb6692e8bfda4400331f34af42ad.setContent(html_93cadfe747e9c2ab075e3865485e1ec7);
#
#
#
#         marker_f55049459e821b1830ba004180e01a50.bindPopup(popup_76c8bb6692e8bfda4400331f34af42ad)
#         ;
#
#
#
#
#             var marker_4eba91d2a3f0fd6f6ccce0de10435541 = L.marker(
#                 [-22.731597923018892, -43.57336899433781],
#                 {
# }
#             ).addTo(map_6d74fedf09ba6df80472d9085efa4f07);
#
#
#         var popup_854e6be27341cce02484151577024176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# })

# %% [markdown]
# # Parte 2

# %%
# Criando um novo mapa base
mapa2 = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

# Adicionando marcadores circulares para todos os imóveis
for _, imovel in df_mapa.iterrows():

    if imovel['cidade'] == 'Nova Iguaçu':
        cor = 'blue'
    else:
        cor = 'orange'

    folium.CircleMarker(
        location=[imovel['latitude'], imovel['longitude']],
        radius=8,
        color=cor,
        fill=True,
        fill_color=cor,
        tooltip='Clique para detalhes'
    ).add_to(mapa2)

mapa2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d3474879b2a045b720481c68dff7afc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d3474879b2a045b720481c68dff7afc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d3474879b2a045b720481c68dff7afc = L.map(
#                 &quot;map_8d3474879b2a045b720481c68dff7afc&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_132bf75fffd9ac8eb30c7660e4df1acb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_132bf75fffd9ac8eb30c7660e4df1acb.addTo(map_8d3474879b2a045b720481c68dff7afc);
#
#
#             var circle_marker_bf40bb22e75be2ea77527eaf52605726 = L.circleMarker(
#                 [-22.714426310323375, -43.57138840919782],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d3474879b2a045b720481c68dff7afc);
#
#
#             circle_marker_bf40bb22e75be2ea77527eaf52605726.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_dd948f8b11a1bcbb910c81da6ca6c189 = L.circleMarker(
#                 [-22.73755359069016, -43.43988185026465],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d3474879b2a045b720481c68dff7afc);
#
#
#             circle_marker_dd948f8b11a1bcbb910c81da6ca6c189.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_992085899b95070efd8de0df4be94e7e = L.circleMarker(
#                 [-22.73223452200459, -43.4707531961017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d3474879b2a045b720481c68dff7afc);
#
#
#             circle_marker_992085899b95070efd8de0df4be94e7e.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6f11d4192087e7ccf3b62a1f00310450 = L.circleMarker(
#                 [-22.76691979150169, -43.47880888937601],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d3474879b2a045b720481c68dff7afc);
#
#
#             circle_marker_6f11d4192087e7ccf3b62a1f00310450.bindTooltip(
#                 `&lt;div&gt;
#                      Clique para detalhes
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ecfefb4e3a9d4ea816eee12e1be98377 = L.circleMarker(
#                 [-22.731597923018892, -43.

# %% [markdown]
# # Parte 3
#
# Criar o terceiro mapa e o MarkerCluster

# %%
mapa3 = folium.Map(
    location=[latitude_media, longitude_media],
    zoom_start=12,
    tiles='OpenStreetMap'
)

cluster = MarkerCluster().add_to(mapa3)

mapa3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12a7e2959b4063df2105781405cac752 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12a7e2959b4063df2105781405cac752&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12a7e2959b4063df2105781405cac752 = L.map(
#                 &quot;map_12a7e2959b4063df2105781405cac752&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f2c2c12cae983b2c9d5940f4befd41f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f2c2c12cae983b2c9d5940f4befd41f.addTo(map_12a7e2959b4063df2105781405cac752);
#
#
#             var marker_cluster_f4f222920c43a1a3f5b147ec95512943 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_f4f222920c43a1a3f5b147ec95512943.addTo(map_12a7e2959b4063df2105781405cac752);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adicionar todos os imóveis ao cluster com ícones customizados

# %%
for _, imovel in df_mapa.iterrows():

    if imovel['tipo'] == 'Casa':
        cor = 'green'
    elif imovel['tipo'] == 'Apartamento':
        cor = 'blue'
    else:
        cor = 'gray'

    folium.Marker(
        location=[imovel['latitude'], imovel['longitude']],
        popup=f"Tipo: {imovel['tipo']}<br>Valor: R$ {imovel['valor_venda']:.2f}",
        icon=folium.Icon(color=cor)
    ).add_to(cluster)

mapa3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12a7e2959b4063df2105781405cac752 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12a7e2959b4063df2105781405cac752&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12a7e2959b4063df2105781405cac752 = L.map(
#                 &quot;map_12a7e2959b4063df2105781405cac752&quot;,
#                 {
#                     center: [-22.736785025907697, -43.50738358758272],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f2c2c12cae983b2c9d5940f4befd41f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f2c2c12cae983b2c9d5940f4befd41f.addTo(map_12a7e2959b4063df2105781405cac752);
#
#
#             var marker_cluster_f4f222920c43a1a3f5b147ec95512943 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             marker_cluster_f4f222920c43a1a3f5b147ec95512943.addTo(map_12a7e2959b4063df2105781405cac752);
#
#
#             tile_layer_6f2c2c12cae983b2c9d5940f4befd41f.addTo(map_12a7e2959b4063df2105781405cac752);
#
#
#             marker_cluster_f4f222920c43a1a3f5b147ec95512943.addTo(map_12a7e2959b4063df2105781405cac752);
#
#
#             var marker_97eca27a4cfc39ab951fc448579656e6 = L.marker(
#                 [-22.714426310323375, -43.57138840919782],
#                 {
# }
#             ).addTo(marker_cluster_f4f222920c43a1a3f5b147ec95512943);
#
#
#             var icon_ee2292772804f8eaa9deae6226c47182 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_42d7c76f84dfa5dc95ab097ed2194eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c7f86d6f99d51c7a32a34e6808ae751 = $(`&lt;div id=&quot;html_3c7f86d6f99d51c7a32a34e6808ae751&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Casa&lt;br&gt;Valor: R$ 613765.60&lt;/div&gt;`)[0];
#                 popup_42d7c76f84dfa5dc95ab097ed2194eb1.setContent(html_3c7f86d6f99d51c7a32a34e6808ae751);
#
#
#
#         marker_97eca27a4cfc39ab951fc448579656e6.bindPopup(popup_42d7c76f84dfa5dc95ab097ed2194eb1)
#         ;
#
#
#
#
#                 marker_97eca27a4cfc39ab951fc448579656e6.setIcon(icon_ee2292772804f8eaa9deae6226c47182);
#
#
#             var marker_904115a215faf2274c03c8cbf9b813c0 = L.marker(
#                 [-22.73755359069016, -43.43988185026465],
#                 {
# }
#             ).addTo(marker_cluster_f4f222920c43a1a3f5b147ec95512943);
#
#
#             var icon_3c866b10455684790404a1f3a4d801ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;gray&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4d4f9fd59579fd3895c6d0125d438724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64f00a366ce22d7c11e623158769db77 = $(`&lt;div id=&quot;html_64f00a366ce22d7c11e623158769db77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tipo: Terreno&lt;br&gt;Valor: R$ 368197.75&lt;/div&gt;`)[0];
#                 popup_4d4f9fd59579fd3895c6d0125d438724.setContent(html_64f00a366ce22d7c11e623158769db77);
#
#
#
#         marker_904115a215faf2274c03c8cbf9b813c0.bindPopup(popup_4d4f9fd59579fd3895c6d0125d438724)
#         ;
#
#
#
#
#                 marker_904115a215faf2274c03c8cbf9b813c0.setIcon(icon_3c866b10455684790404a1f3a4d801ff);
#
#
#             var marker_ff1f29f1f12b814d37918caee2389812 = L.marker(
#                 [-22.73223452200459, -43.4707531961017],
#                 {
# }
#             ).addTo(marker_cluster_f4f222920c43a1a3f5b147ec95512943);
#
#
#             var icon_3d30

# %% [markdown]
# Salvar o mapa em um arquivo HTML

# %%
mapa3.save('mapa_imoveis_baixada.html')
